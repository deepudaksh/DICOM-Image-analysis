# %%
import numpy as np
import pandas as pd
import pydicom
import glob

# %%
train_dcm_fps = glob.glob('dicom_dir/*.dcm')

# %%
train_dcms = [pydicom.read_file(x, stop_before_pixels=True) for x in train_dcm_fps]

# %%
train_dcms
# Out:
# [(0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
#  (0008, 0012) Instance Creation Date              DA: '19950131'
#  (0008, 0013) Instance Creation Time              TM: '091428'
#  (0008, 0016) SOP Class UID                       UI: CT Image Storage
#  (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.266402896965029418188277260373
#  (0008, 0020) Study Date                          DA: '19950131'
#  (0008, 0021) Series Date                         DA: '19950131'
#  (0008, 0022) Acquisition Date                    DA: '19950131'
#  (0008, 0023) Content Date                        DA: '19950131'
#  (0008, 0030) Study Time                          TM: '083043'
#  (0008, 0031) Series Time                         TM: '091346'
#  (0008, 0032) Acquisition Time                    TM: '091400'
#  (0008, 0033) Content Time                        TM: '091428'
#  (0008, 0050) Accession Number                    SH: '9688812014390983'
#  (0008, 0060) Modality                            CS: 'CT'
#  (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
#  (0008, 0090) Referring Physician's Name          PN: ' '
#  (0008, 1030) Study Description                   LO: 'CT FNA RT + LT LUNG'
#  (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'CTFULTD'
#     (0008, 0104) Code Meaning                        LO: 'CT LIMITED OR LOCALIZED FOLLOW UP STUDY'
#     ---------
#  (0008, 103e) Series Description                  LO: 'PRE SCAN'
#  (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
#  (0009, 0010) Private Creator                     LO: 'GEMS_IDEN_01'
#  (0009, 1002) [Suite id]                          SH: 'CT12'
#  (0009, 1004) [Product id]                        SH: 'LightSpeed VCT'
#  (0010, 0010) Patient's Name                      PN: 'TCGA-34-8455'
#  (0010, 0020) Patient ID                          LO: 'TCGA-34-8455'
#  (0010, 0030) Patient's Birth Date                DA: ''
#  (0010, 0040) Patient's Sex                       CS: 'M'
#  (0010, 1010) Patient's Age                       AS: '067Y'
#  (0010, 21b0) Additional Patient History          LT: 'CT FNA RT + LT LUNG'
#  (0012, 0062) Patient Identity Removed            CS: 'YES'
#  (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
#  (0012, 0064)  De-identification Method Code Sequence   7 item(s) ----
#     (0008, 0100) Code Value                          SH: '113100'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#     ---------
#     (0008, 0100) Code Value                          SH: '113101'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113105'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113107'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113108'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113109'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113111'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#     ---------
#  (0013, 0010) Private Creator                     LO: 'CTP'
#  (0013, 1010) Private tag data                    UN: b'TCGA-LUSC\x00'
#  (0013, 1013) Private tag data                    UN: b'64504012'
#  (0018, 0015) Body Part Examined                  CS: 'LUNG'
#  (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
#  (0018, 0050) Slice Thickness                     DS: "2.500000"
#  (0018, 0060) KVP                                 DS: "120"
#  (0018, 0090) Data Collection Diameter            DS: "500.000000"
#  (0018, 1020) Software Version(s)                 LO: '07MW18.4'
#  (0018, 1030) Protocol Name                       LO: '5.14 ***OR LUNG BIOPSY/TUMOR ABLATION****'
#  (0018, 1100) Reconstruction Diameter             DS: "360.000000"
#  (0018, 1110) Distance Source to Detector         DS: "949.075012"
#  (0018, 1111) Distance Source to Patient          DS: "541.000000"
#  (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
#  (0018, 1130) Table Height                        DS: "173.000000"
#  (0018, 1140) Rotation Direction                  CS: 'CW'
#  (0018, 1150) Exposure Time                       IS: "1000"
#  (0018, 1151) X-Ray Tube Current                  IS: "160"
#  (0018, 1152) Exposure                            IS: "7"
#  (0018, 1160) Filter Type                         SH: 'BODY FILTER'
#  (0018, 1170) Generator Power                     IS: "19200"
#  (0018, 1190) Focal Spot(s)                       DS: "0.700000"
#  (0018, 1210) Convolution Kernel                  SH: 'SOFT'
#  (0018, 5100) Patient Position                    CS: 'FFS'
#  (0018, 9305) Revolution Time                     FD: 1.0
#  (0018, 9306) Single Collimation Width            FD: 0.625
#  (0018, 9307) Total Collimation Width             FD: 40.0
#  (0018, 9309) Table Speed                         FD: 55.0
#  (0018, 9310) Table Feed per Rotation             FD: 55.0
#  (0018, 9311) Spiral Pitch Factor                 FD: 1.375
#  (0019, 0010) Private Creator                     LO: 'GEMS_ACQU_01'
#  (0019, 1002) [Detector Channel]                  SL: 912
#  (0019, 1003) [Cell number at Theta]              DS: "389.750000"
#  (0019, 1004) [Cell spacing]                      DS: "1.023900"
#  (0019, 100f) [Horiz. Frame of ref.]              DS: "2013.500000"
#  (0019, 1011) [Series contrast]                   SS: 0
#  (0019, 1018) [First scan ras]                    LO: 'S'
#  (0019, 101a) [Last scan ras]                     LO: 'I'
#  (0019, 1023) [Table Speed [mm/rotation]]         DS: "55.000000"
#  (0019, 1024) [Mid Scan Time [sec]]               DS: "2507.132812"
#  (0019, 1025) [Mid scan flag]                     SS: 1
#  (0019, 1026) [Tube Azimuth [degree]]             SL: 357
#  (0019, 1027) [Rotation Speed [msec]]             DS: "1.000000"
#  (0019, 102c) [Number of triggers]                SL: 5891
#  (0019, 102e) [Angle of first view]               DS: "0.000000"
#  (0019, 102f) [Trigger frequency]                 DS: "984.000000"
#  (0019, 1039) [SFOV Type]                         SS: 1024
#  (0019, 1042) [Segment Number]                    SS: 0
#  (0019, 1043) [Total Segments Required]           SS: 0
#  (0019, 1047) [View compression factor]           SS: 1
#  (0019, 1052) [Recon post proc. Flag]             SS: 1
#  (0019, 106a) [Dependent on #views processed]     SS: 3
#  (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.276420868543955019823048266164
#  (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.817843454204409022668627882451
#  (0020, 0010) Study ID                            SH: ''
#  (0020, 0011) Series Number                       IS: "6"
#  (0020, 0012) Acquisition Number                  IS: "1"
#  (0020, 0013) Instance Number                     IS: "58"
#  (0020, 0032) Image Position (Patient)            DS: ['-161.400', '-165.000', '-172.000']
#  (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
#  (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.944500219387191576742785668225
#  (0020, 1040) Position Reference Indicator        LO: 'SN'
#  (0020, 1041) Slice Location                      DS: "-172.000"
#  (0021, 0010) Private Creator                     LO: 'GEMS_RELA_01'
#  (0021, 1003) [Series from which Prescribed]      SS: 6
#  (0021, 1035) [Series from which prescribed]      SS: 5
#  (0021, 1036) [Image from which prescribed]       SS: 2
#  (0021, 1091) [Biopsy position]                   SS: 0
#  (0021, 1092) [Biopsy T location]                 FL: 0.0
#  (0021, 1093) [Biopsy ref location]               FL: 0.0
#  (0023, 0010) Private Creator                     LO: 'GEMS_STDY_01'
#  (0027, 0010) Private Creator                     LO: 'GEMS_IMAG_01'
#  (0027, 1010) [Scout Type]                        SS: 0
#  (0027, 101c) [Vma mamp]                          SL: 0
#  (0027, 101e) [Vma mod]                           SL: 0
#  (0027, 101f) [Vma clip]                          SL: 0
#  (0027, 1020) [Smart scan ON/OFF flag]            SS: 0
#  (0027, 1035) [Plane Type]                        SS: 2
#  (0027, 1042) [Center R coord of plane image]     FL: -18.600000381469727
#  (0027, 1043) [Center A coord of plane image]     FL: -15.0
#  (0027, 1044) [Center S coord of plane image]     FL: -172.0
#  (0027, 1045) [Normal R coord]                    FL: 0.0
#  (0027, 1046) [Normal A coord]                    FL: 0.0
#  (0027, 1047) [Normal S coord]                    FL: -1.0
#  (0027, 1050) [Scan Start Location]               FL: 0.0
#  (0027, 1051) [Scan End Location]                 FL: 0.0
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: ['0.703125', '0.703125']
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 0120) Pixel Padding Value                 SS: -2000
#  (0028, 0303) Longitudinal Temporal Information M SH: 'MODIFIED'
#  (0028, 1050) Window Center                       DS: "40"
#  (0028, 1051) Window Width                        DS: "400"
#  (0028, 1052) Rescale Intercept                   DS: "-1024"
#  (0028, 1053) Rescale Slope                       DS: "1"
#  (0028, 1054) Rescale Type                        LO: 'HU'
#  (0040, 0244) Performed Procedure Step Start Date DA: '19950131'
#  (0040, 0245) Performed Procedure Step Start Time TM: '083043'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'CT FNA RT + LT LUNG'
#  (0043, 0010) Private Creator                     LO: 'GEMS_PARM_01'
#  (0043, 1010) [Window value]                      US: 400
#  (0043, 1012) [X-ray chain]                       SS: [99, 99, 99]
#  (0043, 1016) [Number of overranges]              SS: -1
#  (0043, 101e) [Delta Start Time [msec]]           DS: "2.669715"
#  (0043, 101f) [Max overranges in a view]          SL: 0
#  (0043, 1021) [Corrected after glow terms]        SS: 0
#  (0043, 1025) [Reference channels]                SS: [0, 0, 0, 0, 0, 0]
#  (0043, 1026) [No views ref chans blocked]        US: [0, 0, 0, 0]
#  (0043, 1027) [Scan Pitch Ratio]                  SH: '1.375:1'
#  (0043, 102b) [Private Scan Options]              SS: [2, 0, 0, 0]
#  (0043, 1031) [Recon Center Coordinates]          DS: ['-18.600000', '-15.000000']
#  (0043, 1040) [Trigger on position]               FL: 264.3782958984375
#  (0043, 1041) [Degree of rotation]                FL: 2155.243896484375
#  (0043, 1042) [DAS trigger source]                SL: 0
#  (0043, 1043) [DAS fpa gain]                      SL: 0
#  (0043, 1044) [DAS output source]                 SL: 0
#  (0043, 1045) [DAS ad input]                      SL: 0
#  (0043, 1046) [DAS cal mode]                      SL: 0
#  (0043, 104d) [Start scan to X-ray on delay]      FL: 0.0
#  (0043, 104e) [Duration of X-ray on]              FL: 5.986788749694824
#  (0043, 1064) [Image Filter]                      CS: ''
#  (0045, 0010) Private Creator                     LO: 'GEMS_HELIOS_01'
#  (0045, 1001) [Number of Macro Rows in Detector]  SS: 64
#  (0045, 1002) [Macro width at ISO Center]         FL: 0.625
#  (0045, 1003) [DAS type]                          SS: 15
#  (0045, 1004) [DAS gain]                          SS: 4
#  (0045, 1006) [Table Direction]                   CS: 'OUT OF GANTRY'
#  (0045, 1007) [Z smoothing Factor]                FL: 0.0
#  (0045, 1008) [View Weighting Mode]               SS: 0
#  (0045, 1009) [Sigma Row number]                  SS: 0
#  (0045, 100a) [Minimum DAS value]                 FL: 0.0
#  (0045, 100b) [Maximum Offset Value]              FL: 0.0
#  (0045, 100c) [Number of Views shifted]           SS: 0
#  (0045, 100d) [Z tracking Flag]                   SS: 0
#  (0045, 100e) [Mean Z error]                      FL: 0.0
#  (0045, 100f) [Z tracking Error]                  FL: 0.0
#  (0045, 1010) [Start View 2A]                     SS: 0
#  (0045, 1011) [Number of Views 2A]                SS: 0
#  (0045, 1012) [Start View 1A]                     SS: 0
#  (0045, 1013) [Sigma Mode]                        SS: 0
#  (0045, 1014) [Number of Views 1A]                SS: 0
#  (0045, 1015) [Start View 2B]                     SS: 0
#  (0045, 1016) [Number Views 2B]                   SS: 0
#  (0045, 1017) [Start View 1B]                     SS: 0
#  (0045, 1018) [Number of Views 1B]                SS: 0
#  (0045, 1021) [Iterbone Flag]                     SS: 0
#  (0045, 1022) [Perisstaltic Flag]                 SS: 0
#  (0045, 1032) [TemporalResolution]                FL: 1.0
#  (0045, 103b) [NoiseReductionImageFilterDesc]     LO: ''
#  (0073, 0010) Private Creator                     LO: 'STENTOR',
#  (0008, 0000) Group Length                        UL: 442
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM4 SPI']
#  (0008, 0016) SOP Class UID                       UI: CT Image Storage
#  (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.387504037568598956570909585559
#  (0008, 0020) Study Date                          DA: '19860531'
#  (0008, 0021) Series Date                         DA: '19860531'
#  (0008, 0022) Acquisition Date                    DA: '19860531'
#  (0008, 0023) Content Date                        DA: '19860531'
#  (0008, 0030) Study Time                          TM: '101136.000000'
#  (0008, 0031) Series Time                         TM: '101438.513000'
#  (0008, 0032) Acquisition Time                    TM: '101450.982000'
#  (0008, 0033) Content Time                        TM: '101447.446000'
#  (0008, 0040) Data Set Type                       US: 0
#  (0008, 0041) Data Set Subtype                    LO: 'IMA SPI'
#  (0008, 0050) Accession Number                    SH: '1654061970756517'
#  (0008, 0060) Modality                            CS: 'CT'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 0090) Referring Physician's Name          PN: ' '
#  (0008, 1010) Station Name                        SH: ''
#  (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM PLUS 4'
#  (0008, 2111) Derivation Description              ST: ''
#  (0009, 0000) Private Creator                     UN: b'\x86\x00\x00\x00'
#  (0009, 0010) Private tag data                    LO: 'SPI RELEASE 1'
#  (0009, 0012) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
#  (0009, 0013) Private tag data                    LO: 'SIEMENS CM VA0  LAB'
#  (0009, 0020) Private tag data                    LO: 'SIEMENS CT VA0  IDE'
#  (0009, 0030) Private tag data                    LO: 'SIEMENS CT VA0  ORI'
#  (0010, 0000) Group Length                        UL: 70
#  (0010, 0010) Patient's Name                      PN: 'TCGA-17-Z058'
#  (0010, 0020) Patient ID                          LO: 'TCGA-17-Z058'
#  (0010, 0030) Patient's Birth Date                DA: ''
#  (0010, 0040) Patient's Sex                       CS: 'M'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0011, 0000) Private Creator                     UN: b'F\x00\x00\x00'
#  (0011, 0010) Private tag data                    LO: 'SPI RELEASE 1'
#  (0011, 0011) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
#  (0011, 0012) Private tag data                    LO: 'SIEMENS ISI'
#  (0012, 0000) Group Length                        UL: 758
#  (0012, 0062) Patient Identity Removed            CS: 'YES'
#  (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
#  (0012, 0064)  De-identification Method Code Sequence   8 item(s) ----
#     (0008, 0000) Group Length                        UL: 76
#     (0008, 0100) Code Value                          SH: '113100'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#     ---------
#     (0008, 0000) Group Length                        UL: 58
#     (0008, 0100) Code Value                          SH: '113101'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 56
#     (0008, 0100) Code Value                          SH: '113103'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Graphics Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 58
#     (0008, 0100) Code Value                          SH: '113105'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 80
#     (0008, 0100) Code Value                          SH: '113107'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 72
#     (0008, 0100) Code Value                          SH: '113108'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 64
#     (0008, 0100) Code Value                          SH: '113109'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 60
#     (0008, 0100) Code Value                          SH: '113111'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#     ---------
#  (0013, 0000) Private Creator                     UN: b'.\x00\x00\x00'
#  (0013, 0010) Private tag data                    LO: 'CTP'
#  (0013, 1010) Private tag data                    UN: b'TCGA-LUAD\x00'
#  (0013, 1013) Private tag data                    UN: b'77779002'
#  (0018, 0000) Group Length                        UL: 350
#  (0018, 0015) Body Part Examined                  CS: 'CHEST'
#  (0018, 0020) Scanning Sequence                   CS: 'RM'
#  (0018, 0050) Slice Thickness                     DS: "005.000000E+00"
#  (0018, 0060) KVP                                 DS: "000140"
#  (0018, 0090) Data Collection Diameter            DS: "000500"
#  (0018, 1000) Device Serial Number                LO: '                     21003'
#  (0018, 1020) Software Version(s)                 LO: 'VC10C'
#  (0018, 1110) Distance Source to Detector         DS: "001005"
#  (0018, 1111) Distance Source to Patient          DS: "000570"
#  (0018, 1120) Gantry/Detector Tilt                DS: "000.000000E+00"
#  (0018, 1130) Table Height                        DS: "001.620000E+02"
#  (0018, 1140) Rotation Direction                  CS: 'CW'
#  (0018, 1150) Exposure Time                       IS: "750"
#  (0018, 1151) X-Ray Tube Current                  IS: "189"
#  (0018, 1152) Exposure                            IS: "142"
#  (0018, 1170) Generator Power                     IS: "26"
#  (0018, 1190) Focal Spot(s)                       DS: "001.200000E+00"
#  (0018, 1200) Date of Last Calibration            DA: '19860531'
#  (0018, 1201) Time of Last Calibration            TM: '060722.597000'
#  (0018, 1210) Convolution Kernel                  SH: '59 .10.AB50'
#  (0018, 1600) Shutter Shape                       CS: ''
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0019, 0000) Private Creator                     UN: b' \x01\x00\x00'
#  (0019, 0010) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
#  (0019, 0011) Private tag data                    LO: 'SIEMENS CT VA0  GEN'
#  (0019, 0013) Private tag data                    LO: 'SIEMENS CT VA0  COAD'
#  (0019, 0015) Private tag data                    LO: 'SIEMENS CM VA0  ACQU'
#  (0019, 0016) Private tag data                    LO: 'SIEMENS DLR.01'
#  (0019, 0017) Private tag data                    LO: 'SIEMENS SIENET'
#  (0019, 1392) [Osteo Regression Line Slope]       UN: b'009.790000E-01'
#  (0019, 1393) [Osteo Regression Line Intercept]   UN: b'-01.420000E+00'
#  (0019, 13b0) [Feed per Rotation]                 UN: b'008.000000E+00'
#  (0019, 13c0) [Pulmo Water]                       UN: b'-09.999000E+03'
#  (0019, 13c1) [Pulmo Air]                         UN: b'-09.999000E+03'
#  (0019, 13c3) [Pulmo Time]                        UN: b'010000.000000 '
#  (0020, 0000) Group Length                        UL: 574
#  (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.695251996732711525695705170858
#  (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.246606807181055791884070217538
#  (0020, 0010) Study ID                            SH: ''
#  (0020, 0011) Series Number                       IS: "000005"
#  (0020, 0012) Acquisition Number                  IS: "000005"
#  (0020, 0013) Instance Number                     IS: "000060"
#  (0020, 0030) Image Position                      DS: ['-01.671768E+02', '-1.651768E+02', '-4.740000E+02']
#  (0020, 0032) Image Position (Patient)            DS: ['-167.50001', '-165.50001', '-474']
#  (0020, 0035) Image Orientation                   DS: ['001.000000E+00', '00.000000E+00', '00.000000E+00', '00.000000E+00', '01.000000E+00', '00.000000E+00']
#  (0020, 0037) Image Orientation (Patient)         DS: ['1', '0', '0', '0', '1', '0']
#  (0020, 0050) Location                            DS: "-04.740000E+02"
#  (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.262416875659531075526897459569
#  (0020, 0070) Image Geometry Type                 LO: 'PLANAR'
#  (0020, 0080) Masking Image                       CS: ''
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: "-474"
#  (0020, 3100) Source Image IDs                    CS: ''
#  (0020, 3402) Modified Image ID                   CS: ''
#  (0020, 3403) Modified Image Date                 DA: ''
#  (0020, 3405) Modified Image Time                 TM: ''
#  (0020, 5000) Original Image Identification       AT: ['']
#  (0020, 5002) Original Image Identification Nomen LO: ''
#  (0021, 0000) Private Creator                     UN: b'\x84\x00\x00\x00'
#  (0021, 0010) Private tag data                    LO: 'SIEMENS MED'
#  (0021, 0011) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
#  (0021, 0012) Private tag data                    LO: 'SIEMENS CT VA0  GEN'
#  (0021, 0022) Private tag data                    LO: 'SIEMENS CT VA0  RAW'
#  (0021, 0030) Private tag data                    LO: 'SIEMENS CT VA0  ORMR'
#  (0028, 0000) Group Length                        UL: 268
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0005) Image Dimensions                    US: 2
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: ['006.464844E-01', '06.464844E-01']
#  (0028, 0040) Image Format                        CS: 'RECT'
#  (0028, 0050) Manipulated Image                   LO: ''
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0200) Image Location                      US: 32736
#  (0028, 0301) Burned In Annotation                CS: 'NO'
#  (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
#  (0028, 1050) Window Center                       DS: ['000029', '-0550']
#  (0028, 1051) Window Width                        DS: ['000400', '01800']
#  (0028, 1052) Rescale Intercept                   DS: "-1024.000000"
#  (0028, 1053) Rescale Slope                       DS: "1.000000"
#  (0029, 0000) Private Creator                     UN: b'N\x00\x00\x00'
#  (0029, 0011) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
#  (0029, 0030) Private tag data                    LO: 'SIEMENS MED MG'
#  (0029, 0031) Private tag data                    LO: 'SIEMENS MED DISPLAY'
#  (0031, 0000) Private Creator                     UN: b'\x14\x00\x00\x00'
#  (0031, 0012) Private tag data                    LO: 'SIEMENS ISI'
#  (0032, 0000) Group Length                        UL: 8
#  (0032, 4000) Study Comments                      LT: ''
#  (0040, 0000) Group Length                        UL: 16
#  (0040, 0009) Scheduled Procedure Step ID         SH: ''
#  (0040, 1003) Requested Procedure Priority        SH: ''
#  (0091, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
#  (0091, 0010) Private tag data                    LO: 'SIENET'
#  (0095, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
#  (0095, 0010) Private tag data                    LO: 'SIENET'
#  (0097, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
#  (0097, 0010) Private tag data                    LO: 'SIENET'
#  (0099, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
#  (0099, 0010) Private tag data                    LO: 'SIENET'
#  (7fe0, 0000) Group Length                        UL: 524296,
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
#  (0008, 0016) SOP Class UID                       UI: CT Image Storage
#  (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.7777.4012.627830717640817292230199045223
#  (0008, 0020) Study Date                          DA: '20060122'
#  (0008, 0021) Series Date                         DA: '20060122'
#  (0008, 0022) Acquisition Date                    DA: '20060122'
#  (0008, 0023) Content Date                        DA: '20060122'
#  (0008, 0030) Study Time                          TM: '121518.765000'
#  (0008, 0031) Series Time                         TM: '122129.234000'
#  (0008, 0032) Acquisition Time                    TM: '122107.023584'
#  (0008, 0033) Content Time                        TM: '122107.023584'
#  (0008, 0040) Data Set Type                       US: 0
#  (0008, 0041) Data Set Subtype                    LO: 'IMA NONE'
#  (0008, 0050) Accession Number                    SH: '4593449648922709'
#  (0008, 0060) Modality                            CS: 'CT'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 0090) Referring Physician's Name          PN: ' '
#  (0008, 1030) Study Description                   LO: 'Abdomen^02_Chest_Abd (Adult)'
#  (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'JCT71260'
#     (0008, 0102) Coding Scheme Designator            SH: 'DTL_SVC_CD'
#     (0008, 0104) Code Meaning                        LO: '71260 CT Chest with contrast'
#     ---------
#  (0008, 103e) Series Description                  LO: 'Chest/Abd  3.0  B20f'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Sensation 64'
#  (0009, 0010) Private Creator                     LO: 'SIEMENS CT VA1 DUMMY'
#  (0009, 0011) Private Creator                     LO: 'SPI RELEASE 1'
#  (0010, 0010) Patient's Name                      PN: 'TCGA-92-7340'
#  (0010, 0020) Patient ID                          LO: 'TCGA-92-7340'
#  (0010, 0030) Patient's Birth Date                DA: ''
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '045Y'
#  (0010, 21a0) Smoking Status                      CS: 'NO'
#  (0010, 21c0) Pregnancy Status                    US: 1
#  (0011, 0010) Private Creator                     LO: 'SPI RELEASE 1'
#  (0012, 0062) Patient Identity Removed            CS: 'YES'
#  (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
#  (0012, 0064)  De-identification Method Code Sequence   7 item(s) ----
#     (0008, 0100) Code Value                          SH: '113100'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#     ---------
#     (0008, 0100) Code Value                          SH: '113101'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113105'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113107'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113108'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113109'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113111'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#     ---------
#  (0013, 0010) Private Creator                     LO: 'CTP'
#  (0013, 1010) Private tag data                    LO: 'TCGA-LUSC'
#  (0013, 1013) Private tag data                    LO: '77774012'
#  (0018, 0015) Body Part Examined                  CS: 'LUNG'
#  (0018, 0050) Slice Thickness                     DS: "3"
#  (0018, 0060) KVP                                 DS: "120"
#  (0018, 0090) Data Collection Diameter            DS: "500"
#  (0018, 1000) Device Serial Number                LO: '54961'
#  (0018, 1020) Software Version(s)                 LO: 'syngo CT 2007S'
#  (0018, 1030) Protocol Name                       LO: '02_Chest_Abd'
#  (0018, 1100) Reconstruction Diameter             DS: "394"
#  (0018, 1110) Distance Source to Detector         DS: "1040"
#  (0018, 1111) Distance Source to Patient          DS: "570"
#  (0018, 1120) Gantry/Detector Tilt                DS: "0"
#  (0018, 1130) Table Height                        DS: "175"
#  (0018, 1140) Rotation Direction                  CS: 'CW'
#  (0018, 1150) Exposure Time                       IS: "500"
#  (0018, 1151) X-Ray Tube Current                  IS: "436"
#  (0018, 1152) Exposure                            IS: "218"
#  (0018, 1160) Filter Type                         SH: '0'
#  (0018, 1170) Generator Power                     IS: "57"
#  (0018, 1190) Focal Spot(s)                       DS: "1.2"
#  (0018, 1200) Date of Last Calibration            DA: '20060122'
#  (0018, 1201) Time of Last Calibration            TM: '064544.000000'
#  (0018, 1210) Convolution Kernel                  SH: 'B20f'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0019, 0010) Private Creator                     LO: 'SIEMENS CT VA0  COAD'
#  (0019, 10b0) [Feed per Rotation]                 UN: b'19.2'
#  (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7777.4012.450770664900019194206481282581
#  (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7777.4012.690957267784060587771729198271
#  (0020, 0010) Study ID                            SH: ''
#  (0020, 0011) Series Number                       IS: "2"
#  (0020, 0012) Acquisition Number                  IS: "2"
#  (0020, 0013) Instance Number                     IS: "174"
#  (0020, 0032) Image Position (Patient)            DS: ['-179.615234375', '-371.615234375', '-324']
#  (0020, 0037) Image Orientation (Patient)         DS: ['1', '0', '0', '0', '1', '0']
#  (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.7777.4012.220565058496647834512836124498
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: "-324"
#  (0021, 0010) Private Creator                     LO: 'SIEMENS MED'
#  (0021, 1011) [Target]                            UN: b'17\\0'
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: ['0.76953125', '0.76953125']
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0106) Smallest Image Pixel Value          US: 0
#  (0028, 0107) Largest Image Pixel Value           US: 2349
#  (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
#  (0028, 1050) Window Center                       DS: ['30', '-550']
#  (0028, 1051) Window Width                        DS: ['400', '1800']
#  (0028, 1052) Rescale Intercept                   DS: "-1024"
#  (0028, 1053) Rescale Slope                       DS: "1"
#  (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
#  (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
#  (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#  (0032, 1060) Requested Procedure Description     LO: '71260 CT Chest with contrast'
#  (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'JCT71260'
#     (0008, 0102) Coding Scheme Designator            SH: 'DTL_SVC_CD'
#     (0008, 0104) Code Meaning                        LO: '71260 CT Chest with contrast'
#     ---------
#  (0040, 1003) Requested Procedure Priority        SH: 'T'
#  (0073, 0010) Private Creator                     LO: 'STENTOR'
#  (0091, 0010) Private Creator                     LO: 'SIENET'
#  (0095, 0010) Private Creator                     LO: 'SIENET'
#  (0097, 0010) Private Creator                     LO: 'SIENET'
#  (0099, 0010) Private Creator                     LO: 'SIENET',
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
#  (0008, 0012) Instance Creation Date              DA: '19950925'
#  (0008, 0013) Instance Creation Time              TM: '125529'
#  (0008, 0016) SOP Class UID                       UI: CT Image Storage
#  (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.257671962215014126531523995137
#  (0008, 0020) Study Date                          DA: '19950925'
#  (0008, 0021) Series Date                         DA: '19950925'
#  (0008, 0022) Acquisition Date                    DA: '19950925'
#  (0008, 0023) Content Date                        DA: '19950925'
#  (0008, 0030) Study Time                          TM: '125245'
#  (0008, 0031) Series Time                         TM: '125408'
#  (0008, 0032) Acquisition Time                    TM: '125421'
#  (0008, 0033) Content Time                        TM: '125529'
#  (0008, 0050) Accession Number                    SH: '2742670273698499'
#  (0008, 0060) Modality                            CS: 'CT'
#  (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
#  (0008, 0090) Referring Physician's Name          PN: ' '
#  (0008, 1030) Study Description                   LO: 'CT CHEST WITHOUT CONTR'
#  (0008, 103e) Series Description                  LO: 'Recon 3: SUPER DIMENSION CHEST'
#  (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed16'
#  (0009, 0010) Private Creator                     LO: 'GEMS_IDEN_01'
#  (0009, 1002) [Suite id]                          SH: 'CT03'
#  (0009, 1004) [Product id]                        SH: 'LightSpeed16'
#  (0010, 0010) Patient's Name                      PN: 'TCGA-34-A5IX'
#  (0010, 0020) Patient ID                          LO: 'TCGA-34-A5IX'
#  (0010, 0030) Patient's Birth Date                DA: ''
#  (0010, 0040) Patient's Sex                       CS: 'M'
#  (0010, 1010) Patient's Age                       AS: '080Y'
#  (0010, 21b0) Additional Patient History          LT: 'CA'
#  (0012, 0062) Patient Identity Removed            CS: 'YES'
#  (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
#  (0012, 0064)  De-identification Method Code Sequence   7 item(s) ----
#     (0008, 0100) Code Value                          SH: '113100'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#     ---------
#     (0008, 0100) Code Value                          SH: '113101'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113105'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113107'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113108'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113109'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#     ---------
#     (0008, 0100) Code Value                          SH: '113111'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#     ---------
#  (0013, 0010) Private Creator                     LO: 'CTP'
#  (0013, 1010) Private tag data                    UN: b'TCGA-LUSC\x00'
#  (0013, 1013) Private tag data                    UN: b'64504012'
#  (0018, 0015) Body Part Examined                  CS: 'LUNG'
#  (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
#  (0018, 0050) Slice Thickness                     DS: "1.250000"
#  (0018, 0060) KVP                                 DS: "120"
#  (0018, 0090) Data Collection Diameter            DS: "500.000000"
#  (0018, 1020) Software Version(s)                 LO: '07MW11.10'
#  (0018, 1030) Protocol Name                       LO: '5.3 CHEST UNENHANCED SUP D'
#  (0018, 1100) Reconstruction Diameter             DS: "423.000000"
#  (0018, 1110) Distance Source to Detector         DS: "949.075012"
#  (0018, 1111) Distance Source to Patient          DS: "541.000000"
#  (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
#  (0018, 1130) Table Height                        DS: "183.899994"
#  (0018, 1140) Rotation Direction                  CS: 'CW'
#  (0018, 1150) Exposure Time                       IS: "808"
#  (0018, 1151) X-Ray Tube Current                  IS: "164"
#  (0018, 1152) Exposure                            IS: "5"
#  (0018, 1160) Filter Type                         SH: 'BODY FILTER'
#  (0018, 1170) Generator Power                     IS: "52800"
#  (0018, 1190) Focal Spot(s)                       DS: "1.200000"
#  (0018, 1210) Convolution Kernel                  SH: 'STANDARD'
#  (0018, 5100) Patient Position                    CS: 'FFS'
#  (0018, 9305) Revolution Time                     FD: 0.800000011920929
#  (0018, 9306) Single Collimation Width            FD: 1.25
#  (0018, 9307) Total Collimation Width             FD: 20.0
#  (0018, 9309) Table Speed                         FD: 34.37499948777259
#  (0018, 9310) Table Feed per Rotation             FD: 27.5
#  (0018, 9311) Spiral Pitch Factor                 FD: 1.375
#  (0019, 0010) Private Creator                     LO: 'GEMS_ACQU_01'
#  (0019, 1002) [Detector Channel]                  SL: 912
#  (0019, 1003) [Cell number at Theta]              DS: "389.750000"
#  (0019, 1004) [Cell spacing]                      DS: "1.023900"
#  (0019, 100f) [Horiz. Frame of ref.]              DS: "906.049988"
#  (0019, 1011) [Series contrast]                   SS: 0
#  (0019, 1018) [First scan ras]                    LO: 'S'
#  (0019, 101a) [Last scan ras]                     LO: 'I'
#  (0019, 1023) [Table Speed [mm/rotation]]         DS: "27.500000"
#  (0019, 1024) [Mid Scan Time [sec]]               DS: "5.157724"
#  (0019, 1025) [Mid scan flag]                     SS: 1
#  (0019, 1026) [Tube Azimuth [degree]]             SL: 355
#  (0019, 1027) [Rotation Speed [msec]]             DS: "0.800000"
#  (0019, 102c) [Number of triggers]                SL: 12700
#  (0019, 102e) [Angle of first view]               DS: "0.000000"
#  (0019, 102f) [Trigger frequency]                 DS: "1230.000000"
#  (0019, 1039) [SFOV Type]                         SS: 16
#  (0019, 1042) [Segment Number]                    SS: 0
#  (0019, 1043) [Total Segments Required]           SS: 0
#  (0019, 1047) [View compression factor]           SS: 1
#  (0019, 1052) [Recon post proc. Flag]             SS: 1
#  (0019, 106a) [Dependent on #views processed]     SS: 4
#  (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.277047390956385038712476685075
#  (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.200234714530375524999580843628
#  (0020, 0010) Study ID                            SH: ''
#  (0020, 0011) Series Number                       IS: "4"
#  (0020, 0012) Acquisition Number                  IS: "1"
#  (0020, 0013) Instance Number                     IS: "161"
#  (0020, 0032) Image Position (Patient)            DS: ['-220.300', '-211.500', '-97.500']
#  (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
#  (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.207683565340700864830854185603
#  (0020, 1040) Position Reference Indicator        LO: 'SN'
#  (0020, 1041) Slice Location                      DS: "-97.500"
#  (0021, 0010) Private Creator                     LO: 'GEMS_RELA_01'
#  (0021, 1003) [Series from which Prescribed]      SS: 2
#  (0021, 1035) [Series from which prescribed]      SS: 1
#  (0021, 1036) [Image from which prescribed]       SS: 2
#  (0021, 1091) [Biopsy position]                   SS: 0
#  (0021, 1092) [Biopsy T location]                 FL: 0.0
#  (0021, 1093) [Biopsy ref location]               FL: 0.0
#  (0023, 0010) Private Creator                     LO: 'GEMS_STDY_01'
#  (0027, 0010) Private Creator                     LO: 'GEMS_IMAG_01'
#  (0027, 1010) [Scout Type]                        SS: 0
#  (0027, 101c) [Vma mamp]                          SL: 0
#  (0027, 101e) [Vma mod]                           SL: 0
#  (0027, 101f) [Vma clip]                          SL: 115
#  (0027, 1020) [Smart scan ON/OFF flag]            SS: 1
#  (0027, 1035) [Plane Type]                        SS: 2
#  (0027, 1042) [Center R coord of plane image]     FL: 8.800000190734863
#  (0027, 1043) [Center A coord of plane image]     FL: 0.0
#  (0027, 1044) [Center S coord of plane image]     FL: -97.5
#  (0027, 1045) [Normal R coord]                    FL: 0.0
#  (0027, 1046) [Normal A coord]                    FL: 0.0
#  (0027, 1047) [Normal S coord]                    FL: -1.0
#  (0027, 1050) [Scan Start Location]               FL: 0.0
#  (0027, 1051) [Scan End Location]                 FL: 0.0
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: ['0.826172', '0.826172']
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 0120) Pixel Padding Value                 SS: -2000
#  (0028, 0303) Longitudinal Temporal Information M SH: 'MODIFIED'
#  (0028, 1050) Window Center                       DS: "40"
#  (0028, 1051) Window Width                        DS: "400"
#  (0028, 1052) Rescale Intercept                   DS: "-1024"
#  (0028, 1053) Rescale Slope                       DS: "1"
#  (0028, 1054) Rescale Type                        LO: 'HU'
#  (0040, 0244) Performed Procedure Step Start Date DA: '19950925'
#  (0040, 0245) Performed Procedure Step Start Time TM: '125245'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'CT CHEST WITHOUT CONTR'
#  (0043, 0010) Private Creator                     LO: 'GEMS_PARM_01'
#  (0043, 1010) [Window value]                      US: 400
#  (0043, 1012) [X-ray chain]                       SS: [99, 99, 99]
#  (0043, 1016) [Number of overranges]              SS: 0
#  (0043, 101e) [Delta Start Time [msec]]           DS: "4.753659"
#  (0043, 101f) [Max overranges in a view]          SL: 0
#  (0043, 1021) [Corrected after glow terms]        SS: 0
#  (0043, 1025) [Reference channels]                SS: [0, 0, 0, 0, 0, 0]
#  (0043, 1026) [No views ref chans blocked]        US: [0, 0, 0, 0]
#  (0043, 1027) [Scan Pitch Ratio]                  SH: '1.375:1'
#  (0043, 102b) [Private Scan Options]              SS: [4, 0, 0, 0]
#  (0043, 1031) [Recon Center Coordinates]          DS: ['8.800000', '0.000000']
#  (0043, 1040) [Trigger on position]               FL: 68.60877227783203
#  (0043, 1041) [Degree of rotation]                FL: 4645.85986328125
#  (0043, 1042) [DAS trigger source]                SL: 0
#  (0043, 1043) [DAS fpa gain]                      SL: 0
#  (0043, 1044) [DAS output source]                 SL: 0
#  (0043, 1045) [DAS ad input]                      SL: 0
#  (0043, 1046) [DAS cal mode]                      SL: 0
#  (0043, 104d) [Start scan to X-ray on delay]      FL: 0.0
#  (0043, 104e) [Duration of X-ray on]              FL: 10.325202941894531
#  (0043, 1064) [Image Filter]                      CS: ''
#  (0045, 0010) Private Creator                     LO: 'GEMS_HELIOS_01'
#  (0045, 1001) [Number of Macro Rows in Detector]  SS: 16
# ...
#  (0018, 0015) Body Part Examined                  CS: 'LUNG'
#  (0018, 0050) Slice Thickness                     DS: "5"
#  (0018, 0060) KVP                                 DS: "120"
#  (0018, 0090) Data Collection Diameter            DS: "500"
#  (0018, 1000) Device Serial Number                LO: '50029'
#  (0018, 1020) Software Version(s)                 LO: 'VA70C'
#  (0018, 1030) Protocol Name                       LO: '2 Chest Abd Pelvis'
#  (0018, 1100) Reconstruction Diameter             DS: "336"
#  (0018, 1110) Distance Source to Detector         DS: "1040"
#  (0018, 1111) Distance Source to Patient          DS: "570"
#  (0018, 1120) Gantry/Detector Tilt                DS: "0"
#  (0018, 1130) Table Height                        DS: "191"
#  (0018, 1140) Rotation Direction                  CS: 'CW'
#  (0018, 1150) Exposure Time                       IS: "500"
#  (0018, 1151) X-Ray Tube Current                  IS: "322"
#  (0018, 1152) Exposure                            IS: "161"
#  (0018, 1160) Filter Type                         SH: '0'
#  (0018, 1170) Generator Power                     IS: "48"
#  (0018, 1190) Focal Spot(s)                       DS: "1.2"
#  (0018, 1200) Date of Last Calibration            DA: '19940924'
#  (0018, 1201) Time of Last Calibration            TM: '055533.000000'
#  (0018, 1210) Convolution Kernel                  SH: 'B30f'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0019, 0010) Private Creator                     LO: 'SIEMENS CT VA0  COAD'
#  (0019, 10b0) [Feed per Rotation]                 UN: b'24'
#  (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.8421.4012.199748350933579231876022290983
#  (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.8421.4012.905460266874649251053314776511
#  (0020, 0010) Study ID                            SH: ''
#  (0020, 0011) Series Number                       IS: "2"
#  (0020, 0012) Acquisition Number                  IS: "2"
#  (0020, 0013) Instance Number                     IS: "31"
#  (0020, 0032) Image Position (Patient)            DS: ['-199.67188', '-358.67188', '53.5']
#  (0020, 0037) Image Orientation (Patient)         DS: ['1', '0', '0', '0', '1', '0']
#  (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.8421.4012.230334871759811539386596599026
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: "53.5"
#  (0020, 4000) Image Comments                      LT: 'eval obstruction\n125mls omni 22g lw ffd'
#  (0021, 0010) Private Creator                     LO: 'SIEMENS MED'
#  (0021, 1011) [Target]                            UN: b'-32\\0 '
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: ['0.65625', '0.65625']
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
#  (0028, 1050) Window Center                       DS: ['70', '-600']
#  (0028, 1051) Window Width                        DS: ['410', '2000']
#  (0028, 1052) Rescale Intercept                   DS: "-1024"
#  (0028, 1053) Rescale Slope                       DS: "1"
#  (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
#  (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
#  (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#  (0029, 0012) Private Creator                     LO: 'MITRA PRESENTATION 1.0'
#  (0029, 1131) [PMTF Information 1]                UN: b'4.0.185012698 '
#  (0029, 1134) [PMTF Information 4]                UN: b'DB TO DICOM '
#  (0031, 0010) Private Creator                     LO: 'AGFA PACS Archive Mirroring 1.0'
#  (0032, 000a) Study Status ID                     CS: 'READ'
#  (0032, 000c) Study Priority ID                   CS: 'MED'
#  (0032, 1030) Reason for Study                    LO: 'EVAL FOR OBSTRUCTION'
#  (0032, 1060) Requested Procedure Description     LO: 'CT ABDOMEN PELVIS W CONT'
#  (0033, 0010) Private Creator                     LO: 'MITRA OBJECT UTF8 ATTRIBUTES 1.0',
#  (0008, 0000) Group Length                        UL: 458
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
#  (0008, 0016) SOP Class UID                       UI: CT Image Storage
#  (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.328880535467784859347191164348
#  (0008, 0020) Study Date                          DA: '19840713'
#  (0008, 0021) Series Date                         DA: '19840713'
#  (0008, 0022) Acquisition Date                    DA: '19840713'
#  (0008, 0023) Content Date                        DA: '19840713'
#  (0008, 0030) Study Time                          TM: '082819.343000'
#  (0008, 0031) Series Time                         TM: '084026.781000'
#  (0008, 0032) Acquisition Time                    TM: '083731.777000'
#  (0008, 0033) Content Time                        TM: '083731.777000'
#  (0008, 0040) Data Set Type                       US: 0
#  (0008, 0041) Data Set Subtype                    LO: 'IMA SPI'
#  (0008, 0050) Accession Number                    SH: '3109136840619464'
#  (0008, 0060) Modality                            CS: 'CT'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 0090) Referring Physician's Name          PN: ' '
#  (0008, 1010) Station Name                        SH: ''
#  (0008, 103e) Series Description                  LO: 'PE-Fast #1'
#  (0008, 1080) Admitting Diagnoses Description     LO: ''
#  (0008, 1090) Manufacturer's Model Name           LO: 'Volume Zoom'
#  (0009, 0000) Private Creator                     UN: b'N\x00\x00\x00'
#  (0009, 0010) Private tag data                    LO: 'SIEMENS CT VA1 DUMMY'
#  (0009, 0011) Private tag data                    LO: 'SPI RELEASE 1'
#  (0009, 0012) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
#  (0010, 0000) Group Length                        UL: 88
#  (0010, 0010) Patient's Name                      PN: 'TCGA-17-Z043'
#  (0010, 0020) Patient ID                          LO: 'TCGA-17-Z043'
#  (0010, 0030) Patient's Birth Date                DA: ''
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '061Y'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0010, 4000) Patient Comments                    LT: ''
#  (0011, 0000) Private Creator                     UN: b'*\x00\x00\x00'
#  (0011, 0010) Private tag data                    LO: 'SPI RELEASE 1'
#  (0011, 0011) Private tag data                    LO: 'SIEMENS ISI'
#  (0012, 0000) Group Length                        UL: 758
#  (0012, 0062) Patient Identity Removed            CS: 'YES'
#  (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
#  (0012, 0064)  De-identification Method Code Sequence   8 item(s) ----
#     (0008, 0000) Group Length                        UL: 76
#     (0008, 0100) Code Value                          SH: '113100'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#     ---------
#     (0008, 0000) Group Length                        UL: 58
#     (0008, 0100) Code Value                          SH: '113101'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 56
#     (0008, 0100) Code Value                          SH: '113103'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Graphics Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 58
#     (0008, 0100) Code Value                          SH: '113105'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 80
#     (0008, 0100) Code Value                          SH: '113107'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 72
#     (0008, 0100) Code Value                          SH: '113108'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 64
#     (0008, 0100) Code Value                          SH: '113109'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#     ---------
#     (0008, 0000) Group Length                        UL: 60
#     (0008, 0100) Code Value                          SH: '113111'
#     (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#     (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#     ---------
#  (0013, 0000) Private Creator                     UN: b'.\x00\x00\x00'
#  (0013, 0010) Private tag data                    LO: 'CTP'
#  (0013, 1010) Private tag data                    UN: b'TCGA-LUAD\x00'
#  (0013, 1013) Private tag data                    UN: b'77779002'
#  (0018, 0000) Group Length                        UL: 262
#  (0018, 0010) Contrast/Bolus Agent                LO: 'APPLIED'
#  (0018, 0015) Body Part Examined                  CS: 'CHEST'
#  (0018, 0050) Slice Thickness                     DS: "3"
#  (0018, 0060) KVP                                 DS: "120"
#  (0018, 1020) Software Version(s)                 LO: 'VA20Q'
#  (0018, 1030) Protocol Name                       LO: 'PE-Fast + 40 and over Delay'
#  (0018, 1100) Reconstruction Diameter             DS: "336"
#  (0018, 1110) Distance Source to Detector         DS: "1040"
#  (0018, 1111) Distance Source to Patient          DS: "570"
#  (0018, 1120) Gantry/Detector Tilt                DS: "0"
#  (0018, 1130) Table Height                        DS: "139"
#  (0018, 1140) Rotation Direction                  CS: 'CW'
#  (0018, 1150) Exposure Time                       IS: "500"
#  (0018, 1151) X-Ray Tube Current                  IS: "391"
#  (0018, 1152) Exposure                            IS: "120"
#  (0018, 1160) Filter Type                         SH: '0'
#  (0018, 1170) Generator Power                     IS: "46"
#  (0018, 1190) Focal Spot(s)                       DS: "1.2"
#  (0018, 1210) Convolution Kernel                  SH: 'B20f'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0019, 0000) Private Creator                     UN: b'\x9e\x00\x00\x00'
#  (0019, 0010) Private tag data                    LO: 'SIEMENS CT VA0  COAD'
#  (0019, 0011) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
#  (0019, 0012) Private tag data                    LO: 'SIEMENS DLR.01'
#  (0019, 0013) Private tag data                    LO: 'SIEMENS SIENET'
#  (0019, 1090) [Osteo Offset]                      UN: b'0 '
#  (0019, 1092) [Osteo Regression Line Slope]       UN: b'0.958 '
#  (0019, 1093) [Osteo Regression Line Intercept]   UN: b'0.86'
#  (0019, 1096) [Osteo Phantom Number]              UN: b'0 '
#  (0019, 10b0) [Feed per Rotation]                 UN: b'16.3'
#  (0020, 0000) Group Length                        UL: 382
#  (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.142043828961014314666225060208
#  (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.134999765519851780539173272100
#  (0020, 0010) Study ID                            SH: ''
#  (0020, 0011) Series Number                       IS: "4"
#  (0020, 0012) Acquisition Number                  IS: "4"
#  (0020, 0013) Instance Number                     IS: "24"
#  (0020, 0030) Image Position                      DS: ['-168', '-168', '0']
#  (0020, 0032) Image Position (Patient)            DS: ['-150', '-307', '-239']
#  (0020, 0035) Image Orientation                   DS: ['1', '0', '0', '0', '1', '0']
#  (0020, 0037) Image Orientation (Patient)         DS: ['1', '0', '0', '0', '1', '0']
#  (0020, 0050) Location                            DS: "-239"
#  (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.199390780590194958655951125957
#  (0020, 0070) Image Geometry Type                 LO: 'PLANAR'
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: "-239"
#  (0021, 0000) Private Creator                     UN: b'\x14\x00\x00\x00'
#  (0021, 0010) Private tag data                    LO: 'SIEMENS MED'
#  (0028, 0000) Group Length                        UL: 290
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0005) Image Dimensions                    US: 2
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: ['006.562500e-01', '006.562500e-01']
#  (0028, 0040) Image Format                        CS: 'RECT'
#  (0028, 0060) Compression Code                    CS: 'NONE'
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0200) Image Location                      US: 32736
#  (0028, 0301) Burned In Annotation                CS: 'NO'
#  (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
#  (0028, 1050) Window Center                       DS: ['80', '-550']
#  (0028, 1051) Window Width                        DS: ['500', '1800']
#  (0028, 1052) Rescale Intercept                   DS: "-1024.000000"
#  (0028, 1053) Rescale Slope                       DS: "1.000244"
#  (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
#  (0029, 0000) Private Creator                     UN: b'T\x00\x00\x00'
#  (0029, 0010) Private tag data                    LO: 'SIEMENS CSA HEADER'
#  (0029, 0011) Private tag data                    LO: 'SIEMENS MEDCOM HEADER'
#  (0029, 0012) Private tag data                    LO: 'SIEMENS MED DISPLAY'
#  (0032, 0000) Group Length                        UL: 90
#  (0032, 000a) Study Status ID                     CS: 'SCHEDULED'
#  (0032, 1000) Scheduled Study Start Date          DA: '19840713'
#  (0032, 1001) Scheduled Study Start Time          TM: '170000.000000'
#  (0032, 1060) Requested Procedure Description     LO: 'CT Hd/Brain w/oBH'
#  (0032, 4000) Study Comments                      LT: ''
#  (0038, 0000) Group Length                        UL: 10
#  (0038, 0050) Special Needs                       LO: 'BH'
#  (0091, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
#  (0091, 0010) Private tag data                    LO: 'SIENET'
#  (0095, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
#  (0095, 0010) Private tag data                    LO: 'SIENET'
#  (0097, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
#  (0097, 0010) Private tag data                    LO: 'SIENET'
#  (0099, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
#  (0099, 0010) Private tag data                    LO: 'SIENET'
#  (7fe0, 0000) Group Length                        UL: 524296]

# %%
def parse_dcm_metadata(dcm):
    unpacked_data = {}
    group_elem_to_keywords = {}
    # iterating here to force conversion from lazy RawDataElement to DataElement
    for d in dcm:
        pass
    # keys are pydicom.tag.BaseTag, values are pydicom.dataelem.DataElement
    for tag, elem in dcm.items():
        tag_group = tag.group
        tag_elem = tag.elem
        keyword = elem.keyword
        group_elem_to_keywords[(tag_group, tag_elem)] = keyword
        value = elem.value
        unpacked_data[keyword] = value
    return unpacked_data, group_elem_to_keywords

train_meta_dicts, tag_to_keyword_train = zip(*[parse_dcm_metadata(x) for x in train_dcms])

# %%
unified_tag_to_key_train = {k:v for dict_ in tag_to_keyword_train for k,v in dict_.items()}

# %%
train_df = pd.DataFrame.from_records(data=train_meta_dicts)

# %%
train_df.head(1)
# Out:
#              AccessionNumber AcquisitionDate  AcquisitionNumber  \
# 0  STENTOR  9688812014390983        19950131                  1
#
#   AcquisitionTime  AcquisitionsInSeries AdditionalPatientHistory  \
# 0          091400                   NaN      CT FNA RT + LT LUNG
#
#   AdmittingDiagnosesDescription Allergies  BitsAllocated  ...  StudyTime  \
# 0                           NaN       NaN             16  ...     083043
#
#   TableFeedPerRotation TableHeight  TableSpeed  TimeOfLastCalibration  \
# 0                 55.0       173.0        55.0                    NaN
#
#   TotalCollimationWidth WindowCenter WindowCenterWidthExplanation WindowWidth  \
# 0                  40.0           40                          NaN         400
#
#    XRayTubeCurrent
# 0              160
#
# [1 rows x 162 columns]

# %%
train_df['PatientAge'] = train_df['PatientAge'].str[1:3]
train_df.to_csv('test.csv', index=False)

# %%
import matplotlib.pyplot as plt # for basic plots
import seaborn as sns # for nicer plots

# %%
print("Modality: {}\nManufacturer: {}\nPatient Age: {}\nPatient Sex: {}\nPatient Name: {}\nPatient ID: {}".format(
    train_df.Modality, 
    train_df.Manufacturer,
    train_df.PatientAge,
    train_df.PatientSex,
    train_df.PatientName,
    train_df.PatientID))
# Out:
# Modality: 0     CT
# 1     CT
# 2     CT
# 3     CT
# 4     CT
# 5     CT
# 6     CT
# 7     CT
# 8     CT
# 9     CT
# 10    CT
# 11    CT
# 12    CT
# 13    CT
# 14    CT
# 15    CT
# 16    CT
# 17    CT
# 18    CT
# 19    CT
# 20    CT
# 21    CT
# 22    CT
# 23    CT
# 24    CT
# 25    CT
# 26    CT
# 27    CT
# 28    CT
# 29    CT
#       ..
# 70    CT
# 71    CT
# 72    CT
# 73    CT
# 74    CT
# 75    CT
# 76    CT
# 77    CT
# 78    CT
# 79    CT
# 80    CT
# 81    CT
# 82    CT
# 83    CT
# 84    CT
# 85    CT
# 86    CT
# 87    CT
# 88    CT
# 89    CT
# 90    CT
# 91    CT
# 92    CT
# 93    CT
# 94    CT
# 95    CT
# 96    CT
# 97    CT
# 98    CT
# 99    CT
# Name: Modality, Length: 100, dtype: object
# Manufacturer: 0     GE MEDICAL SYSTEMS
# 1                SIEMENS
# 2                SIEMENS
# 3     GE MEDICAL SYSTEMS
# 4     GE MEDICAL SYSTEMS
# 5                SIEMENS
# 6     GE MEDICAL SYSTEMS
# 7                SIEMENS
# 8                SIEMENS
# 9                SIEMENS
# 10               SIEMENS
# 11               SIEMENS
# 12               SIEMENS
# 13               SIEMENS
# 14    GE MEDICAL SYSTEMS
# 15               SIEMENS
# 16    GE MEDICAL SYSTEMS
# 17    GE MEDICAL SYSTEMS
# 18    GE MEDICAL SYSTEMS
# 19               SIEMENS
# 20    GE MEDICAL SYSTEMS
# 21               SIEMENS
# 22               SIEMENS
# 23    GE MEDICAL SYSTEMS
# 24               SIEMENS
# 25               SIEMENS
# 26    GE MEDICAL SYSTEMS
# 27               SIEMENS
# 28               SIEMENS
# 29               SIEMENS
#              ...
# 70               SIEMENS
# 71               SIEMENS
# 72               SIEMENS
# 73    GE MEDICAL SYSTEMS
# 74               SIEMENS
# 75               SIEMENS
# 76               SIEMENS
# 77               SIEMENS
# 78               SIEMENS
# 79               SIEMENS
# 80    GE MEDICAL SYSTEMS
# 81               SIEMENS
# 82    GE MEDICAL SYSTEMS
# 83    GE MEDICAL SYSTEMS
# 84               SIEMENS
# 85    GE MEDICAL SYSTEMS
# 86               SIEMENS
# 87               SIEMENS
# 88               SIEMENS
# 89               SIEMENS
# 90               SIEMENS
# 91               SIEMENS
# 92    GE MEDICAL SYSTEMS
# 93               SIEMENS
# 94               SIEMENS
# 95               SIEMENS
# 96               SIEMENS
# 97    GE MEDICAL SYSTEMS
# 98               SIEMENS
# 99               SIEMENS
# Name: Manufacturer, Length: 100, dtype: object
# Patient Age: 0     67
# 1     60
# 2     45
# 3     80
# 4     72
# 5     74
# 6     74
# 7     61
# 8     48
# 9     82
# 10    48
# 11    70
# 12    60
# 13    73
# 14    74
# 15    82
# 16    66
# 17    74
# 18    59
# 19    44
# 20    67
# 21    67
# 22    66
# 23    74
# 24    56
# 25    74
# 26    68
# 27    75
# 28    64
# 29    52
#       ..
# 70    60
# 71    61
# 72    70
# 73    74
# 74    75
# 75    60
# 76    74
# 77    47
# 78    82
# 79    65
# 80    74
# 81    73
# 82    72
# 83    39
# 84    61
# 85    71
# 86    60
# 87    60
# 88    58
# 89    71
# 90    74
# 91    61
# 92    67
# 93    71
# 94    74
# 95    70
# 96    61
# 97    69
# 98    74
# 99    61
# Name: PatientAge, Length: 100, dtype: object
# Patient Sex: 0     M
# 1     M
# 2     F
# 3     M
# 4     F
# 5     F
# 6     M
# 7     M
# 8     F
# 9     F
# 10    F
# 11    M
# 12    M
# 13    F
# 14    F
# 15    F
# 16    M
# 17    M
# 18    M
# 19    F
# 20    F
# 21    M
# 22    M
# 23    F
# 24    F
# 25    F
# 26    M
# 27    M
# 28    M
# 29    M
#      ..
# 70    M
# 71    F
# 72    M
# 73    F
# 74    M
# 75    M
# 76    F
# 77    M
# 78    F
# 79    M
# 80    F
# 81    F
# 82    M
# 83    M
# 84    M
# 85    F
# 86    M
# 87    M
# 88    M
# 89    M
# 90    F
# 91    F
# 92    F
# 93    M
# 94    F
# 95    M
# 96    F
# 97    F
# 98    F
# 99    F
# Name: PatientSex, Length: 100, dtype: object
# Patient Name: 0     TCGA-34-8455
# 1     TCGA-17-Z058
# 2     TCGA-92-7340
# 3     TCGA-34-A5IX
# 4     TCGA-50-5044
# 5     TCGA-51-6867
# 6     TCGA-50-8460
# 7     TCGA-17-Z059
# 8     TCGA-17-Z045
# 9     TCGA-17-Z048
# 10    TCGA-17-Z045
# 11    TCGA-17-Z053
# 12    TCGA-17-Z058
# 13    TCGA-51-4079
# 14    TCGA-50-6595
# 15    TCGA-17-Z013
# 16    TCGA-60-2722
# 17    TCGA-50-8460
# 18    TCGA-34-5236
# 19    TCGA-92-7340
# 20    TCGA-50-5942
# 21    TCGA-17-Z050
# 22    TCGA-17-Z050
# 23    TCGA-50-6595
# 24    TCGA-17-Z039
# 25    TCGA-17-Z051
# 26    TCGA-50-8459
# 27    TCGA-17-Z054
# 28    TCGA-17-Z031
# 29    TCGA-92-8063
#           ...
# 70    TCGA-17-Z058
# 71    TCGA-17-Z043
# 72    TCGA-17-Z053
# 73    TCGA-50-6595
# 74    TCGA-17-Z054
# 75    TCGA-17-Z058
# 76    TCGA-17-Z051
# 77    TCGA-60-2724
# 78    TCGA-17-Z048
# 79    TCGA-51-4080
# 80    TCGA-60-2723
# 81    TCGA-51-4079
# 82    TCGA-34-5231
# 83    TCGA-60-2716
# 84    TCGA-17-Z059
# 85    TCGA-34-5234
# 86    TCGA-17-Z058
# 87    TCGA-17-Z034
# 88    TCGA-92-8064
# 89    TCGA-17-Z029
# 90    TCGA-92-8065
# 91    TCGA-17-Z021
# 92    TCGA-50-5942
# 93    TCGA-17-Z062
# 94    TCGA-60-2695
# 95    TCGA-17-Z053
# 96    TCGA-17-Z021
# 97    TCGA-38-6178
# 98    TCGA-51-6867
# 99    TCGA-17-Z043
# Name: PatientName, Length: 100, dtype: object
# Patient ID: 0     TCGA-34-8455
# 1     TCGA-17-Z058
# 2     TCGA-92-7340
# 3     TCGA-34-A5IX
# 4     TCGA-50-5044
# 5     TCGA-51-6867
# 6     TCGA-50-8460
# 7     TCGA-17-Z059
# 8     TCGA-17-Z045
# 9     TCGA-17-Z048
# 10    TCGA-17-Z045
# 11    TCGA-17-Z053
# 12    TCGA-17-Z058
# 13    TCGA-51-4079
# 14    TCGA-50-6595
# 15    TCGA-17-Z013
# 16    TCGA-60-2722
# 17    TCGA-50-8460
# 18    TCGA-34-5236
# 19    TCGA-92-7340
# 20    TCGA-50-5942
# 21    TCGA-17-Z050
# 22    TCGA-17-Z050
# 23    TCGA-50-6595
# 24    TCGA-17-Z039
# 25    TCGA-17-Z051
# 26    TCGA-50-8459
# 27    TCGA-17-Z054
# 28    TCGA-17-Z031
# 29    TCGA-92-8063
#           ...
# 70    TCGA-17-Z058
# 71    TCGA-17-Z043
# 72    TCGA-17-Z053
# 73    TCGA-50-6595
# 74    TCGA-17-Z054
# 75    TCGA-17-Z058
# 76    TCGA-17-Z051
# 77    TCGA-60-2724
# 78    TCGA-17-Z048
# 79    TCGA-51-4080
# 80    TCGA-60-2723
# 81    TCGA-51-4079
# 82    TCGA-34-5231
# 83    TCGA-60-2716
# 84    TCGA-17-Z059
# 85    TCGA-34-5234
# 86    TCGA-17-Z058
# 87    TCGA-17-Z034
# 88    TCGA-92-8064
# 89    TCGA-17-Z029
# 90    TCGA-92-8065
# 91    TCGA-17-Z021
# 92    TCGA-50-5942
# 93    TCGA-17-Z062
# 94    TCGA-60-2695
# 95    TCGA-17-Z053
# 96    TCGA-17-Z021
# 97    TCGA-38-6178
# 98    TCGA-51-6867
# 99    TCGA-17-Z043
# Name: PatientID, Length: 100, dtype: object
